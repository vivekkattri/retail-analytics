# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / "src"))

# %%
import pandas as pd
from pathlib import Path
from retail_analytics.clean import fix_types,split_Quantity

root=Path.cwd().parent
path=root/"data" / "raw" / "online_retail_II.xlsx"

sheets = pd.read_excel(path, sheet_name=None)
df = pd.concat(list(sheets.values()), ignore_index=True)

clean_df = fix_types(df)
sales, returns = split_Quantity(clean_df)
print(len(sales), len(returns), len(clean_df))
# Out:
# 1044421 22950 1067371
